# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/LidarObjectDetection/VoxelNet/data
## Download
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip

## Unzip
# !unzip data_object_velodyne.zip 'training/*' -d .
# !unzip data_object_image_2.zip 'training/*' -d .
# !unzip data_object_label_2.zip 'training/*' -d .
# !unzip data_object_calib.zip 'training/*' -d .

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/LidarObjectDetection/VoxelNet/data
# %pycat crop.py
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/LidarObjectDetection/VoxelNet/data

# %%
# %%writefile crop.py
import numpy as np
from imageio import imread
from tqdm import tqdm
import glob

CAM = 2

def load_velodyne_points(filename):
    points = np.fromfile(filename, dtype=np.float32).reshape(-1, 4)
    #points = points[:, :3]  # exclude luminance
    return points

def load_calib(calib_dir):
    # P2 * R0_rect * Tr_velo_to_cam * y
    lines = open(calib_dir).readlines()
    lines = [ line.split()[1:] for line in lines ][:-1]
    #
    P = np.array(lines[CAM]).reshape(3,4)
    #
    Tr_velo_to_cam = np.array(lines[5]).reshape(3,4)
    Tr_velo_to_cam = np.concatenate(  [ Tr_velo_to_cam, np.array([0,0,0,1]).reshape(1,4)  ]  , 0     )
    #
    R_cam_to_rect = np.eye(4)
    R_cam_to_rect[:3,:3] = np.array(lines[4][:9]).reshape(3,3)
    #
    P = P.astype('float32')
    Tr_velo_to_cam = Tr_velo_to_cam.astype('float32')
    R_cam_to_rect = R_cam_to_rect.astype('float32')
    return P, Tr_velo_to_cam, R_cam_to_rect

def prepare_velo_points(pts3d_raw):
    '''Replaces the reflectance value by 1, and tranposes the array, so
        points can be directly multiplied by the camera projection matrix'''
    pts3d = pts3d_raw
    # Reflectance > 0
    indices = pts3d[:, 3] > 0
    pts3d = pts3d[indices ,:]
    pts3d[:,3] = 1
    return pts3d.transpose(), indices

def project_velo_points_in_img(pts3d, T_cam_velo, Rrect, Prect):
    '''Project 3D points into 2D image. Expects pts3d as a 4xN
        numpy array. Returns the 2D projection of the points that
        are in front of the camera only an the corresponding 3D points.'''
    # 3D points in camera reference frame.
    pts3d_cam = Rrect.dot(T_cam_velo.dot(pts3d))
    # Before projecting, keep only points with z>0
    # (points that are in fronto of the camera).
    idx = (pts3d_cam[2,:]>=0)
    pts2d_cam = Prect.dot(pts3d_cam[:,idx])
    return pts3d[:, idx], pts2d_cam/pts2d_cam[2,:], idx


def align_img_and_pc(img_dir, pc_dir, calib_dir):
    
    img = imread(img_dir)
    pts = load_velodyne_points( pc_dir )
    P, Tr_velo_to_cam, R_cam_to_rect = load_calib(calib_dir)

    pts3d, indices = prepare_velo_points(pts)
    pts3d_ori = pts3d.copy()
    reflectances = pts[indices, 3]
    pts3d, pts2d_normed, idx = project_velo_points_in_img( pts3d, Tr_velo_to_cam, R_cam_to_rect, P  )
    #print reflectances.shape, idx.shape
    reflectances = reflectances[idx]
    #print reflectances.shape, pts3d.shape, pts2d_normed.shape
    assert reflectances.shape[0] == pts3d.shape[1] == pts2d_normed.shape[1]

    rows, cols = img.shape[:2]

    points = []
    for i in range(pts2d_normed.shape[1]):
        c = int(np.round(pts2d_normed[0,i]))
        r = int(np.round(pts2d_normed[1,i]))
        if c < cols and r < rows and r > 0 and c > 0:
            color = img[r, c, :]
            point = [ pts3d[0,i], pts3d[1,i], pts3d[2,i], reflectances[i], color[0], color[1], color[2], pts2d_normed[0,i], pts2d_normed[1,i]  ]
            points.append(point)

    points = np.array(points)
    return points

# update the following directories
IMG_ROOT = 'training/image_2/'
PC_ROOT = 'training/velodyne/'
CALIB_ROOT = 'training/calib/'

for frame in tqdm(range(0, 7481)):
    img_dir = IMG_ROOT + '%06d.png' % frame
    pc_dir = PC_ROOT + '%06d.bin' % frame
    calib_dir = CALIB_ROOT + '%06d.txt' % frame

    points = align_img_and_pc(img_dir, pc_dir, calib_dir)
    
    output_name = PC_ROOT + '%06d.bin' % frame
    points[:,:4].astype('float32').tofile(output_name)
# Out:
# Writing crop.py

# %%
# !python crop.py
# Out:
# 100% 7481/7481 [2:18:23<00:00,  1.11s/it]

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/LidarObjectDetection/VoxelNet/data
# %cp -av training validation

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/LidarObjectDetection/VoxelNet/data
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/LidarObjectDetection/VoxelNet/data
# number of training files: 59857
# number of validation files: 59857

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/LidarObjectDetection/VoxelNet/data
# %pycat split.py
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/LidarObjectDetection/VoxelNet/data

# %%
# %%writefile split.py

import os
import glob

file_num = []
for dir in ['training', 'validation']:
    i = 0
    for _ in glob.iglob(dir + '/**/**', recursive=True):
      i += 1

    print("number of {} files: {}".format(dir, i))
    file_num.append(i)

assert(file_num[0] == file_num[1])

lines_train = [line.rstrip('\n') for line in open('train.txt')]
lines_val = [line.rstrip('\n') for line in open('val.txt')]

for i in lines_train:
  os.remove('training/image_2/'+i+'.png')
  os.remove('training/label_2/'+i+'.txt')
  os.remove('training/velodyne/'+i+'.bin')
  os.remove('training/calib/'+i+'.txt')

for i in lines_val:
  os.remove('validation/image_2/'+i+'.png')
  os.remove('validation/label_2/'+i+'.txt')
  os.remove('validation/velodyne/'+i+'.bin')
  os.remove('validation/calib/'+i+'.txt')

for dir in ['training', 'validation']:
    i = 0
    for _ in glob.iglob(dir + '/image_2/**/**', recursive=True):
      i += 1
    print("number of {} image files: {}".format(dir, i))

    i = 0
    for _ in glob.iglob(dir + '/label_2/**/**', recursive=True):
      i += 1
    print("number of {} lable files: {}".format(dir, i))
    
    i = 0
    for _ in glob.iglob(dir + '/velodyne/**/**', recursive=True):
      i += 1
    print("number of {} velodyne files: {}".format(dir, i))

    i = 0
    for _ in glob.iglob(dir + '/calib/**/**', recursive=True):
      i += 1
    print("number of {} calib files: {}".format(dir, i))
# Out:
# Overwriting split.py

# %%
# !python split.py
# Out:
# number of training files: 37585
# number of validation files: 37243
# number of training image files: 3770
# number of training lable files: 3770
# number of training velodyne files: 3770
# number of training calib files: 3770
# number of validation image files: 3713
# number of validation lable files: 3713
# number of validation velodyne files: 3713
# number of validation calib files: 3713

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/LidarObjectDetection/VoxelNet
# !zip -r voxelnet_data.zip data
# Out:
# Streaming output truncated to the last 5000 lines.
# updating: data/validation/velodyne/003418.bin (deflated 43%)
# updating: data/validation/velodyne/003420.bin (deflated 39%)
# updating: data/validation/velodyne/003423.bin (deflated 41%)
# updating: data/validation/velodyne/003424.bin (deflated 41%)
# updating: data/validation/velodyne/003427.bin (deflated 38%)
# updating: data/validation/velodyne/003431.bin (deflated 38%)
# updating: data/validation/velodyne/003433.bin (deflated 42%)
# updating: data/validation/velodyne/003436.bin (deflated 40%)
# updating: data/validation/velodyne/003437.bin (deflated 41%)
# updating: data/validation/velodyne/003438.bin (deflated 40%)
# updating: data/validation/velodyne/003439.bin (deflated 41%)
# updating: data/validation/velodyne/003440.bin (deflated 41%)
# updating: data/validation/velodyne/003442.bin (deflated 41%)
# updating: data/validation/velodyne/003441.bin (deflated 41%)
# updating: data/validation/velodyne/003444.bin (deflated 42%)
# updating: data/validation/velodyne/003445.bin (deflated 41%)
# updating: data/validation/velodyne/003446.bin (deflated 40%)
# updating: data/validation/velodyne/003451.bin (deflated 41%)
# updating: data/validation/velodyne/003452.bin (deflated 40%)
# updating: data/validation/velodyne/003454.bin (deflated 38%)
# updating: data/validation/velodyne/003455.bin (deflated 40%)
# updating: data/validation/velodyne/003458.bin (deflated 43%)
# updating: data/validation/velodyne/003457.bin (deflated 40%)
# updating: data/validation/velodyne/003459.bin (deflated 40%)
# updating: data/validation/velodyne/003460.bin (deflated 41%)
# updating: data/validation/velodyne/003463.bin (deflated 40%)
# updating: data/validation/velodyne/003462.bin (deflated 42%)
# updating: data/validation/velodyne/003468.bin (deflated 43%)
# updating: data/validation/velodyne/003472.bin (deflated 40%)
# updating: data/validation/velodyne/003473.bin (deflated 41%)
# updating: data/validation/velodyne/003475.bin (deflated 38%)
# updating: data/validation/velodyne/003476.bin (deflated 42%)
# updating: data/validation/velodyne/003477.bin (deflated 42%)
# updating: data/validation/velodyne/003479.bin (deflated 43%)
# updating: data/validation/velodyne/001482.bin (deflated 41%)
# updating: data/validation/velodyne/001479.bin (deflated 42%)
# updating: data/validation/velodyne/001493.bin (deflated 42%)
# updating: data/validation/velodyne/001492.bin (deflated 40%)
# updating: data/validation/velodyne/001490.bin (deflated 40%)
# updating: data/validation/velodyne/001491.bin (deflated 43%)
# updating: data/validation/velodyne/001494.bin (deflated 43%)
# updating: data/validation/velodyne/001498.bin (deflated 43%)
# updating: data/validation/velodyne/001504.bin (deflated 40%)
# updating: data/validation/velodyne/001499.bin (deflated 41%)
# updating: data/validation/velodyne/001505.bin (deflated 41%)
# updating: data/validation/velodyne/001496.bin (deflated 41%)
# updating: data/validation/velodyne/001500.bin (deflated 40%)
# updating: data/validation/velodyne/001503.bin (deflated 43%)
# updating: data/validation/velodyne/000906.bin (deflated 41%)
# updating: data/validation/velodyne/000918.bin (deflated 41%)
# updating: data/validation/velodyne/000913.bin (deflated 41%)
# updating: data/validation/velodyne/000910.bin (deflated 41%)
# updating: data/validation/velodyne/000914.bin (deflated 42%)
# updating: data/validation/velodyne/000921.bin (deflated 41%)
# updating: data/validation/velodyne/000925.bin (deflated 40%)
# updating: data/validation/velodyne/000927.bin (deflated 41%)
# updating: data/validation/velodyne/000919.bin (deflated 41%)
# updating: data/validation/velodyne/000924.bin (deflated 41%)
# updating: data/validation/velodyne/000929.bin (deflated 42%)
# updating: data/validation/velodyne/000933.bin (deflated 38%)
# updating: data/validation/velodyne/000935.bin (deflated 41%)
# updating: data/validation/velodyne/000936.bin (deflated 40%)
# updating: data/validation/velodyne/000934.bin (deflated 40%)
# updating: data/validation/velodyne/000937.bin (deflated 40%)
# updating: data/validation/velodyne/000941.bin (deflated 40%)
# updating: data/validation/velodyne/000945.bin (deflated 41%)
# updating: data/validation/velodyne/000951.bin (deflated 43%)
# updating: data/validation/velodyne/000947.bin (deflated 42%)
# updating: data/validation/velodyne/000946.bin (deflated 40%)
# updating: data/validation/velodyne/000950.bin (deflated 40%)
# updating: data/validation/velodyne/000954.bin (deflated 42%)
# ...
# updating: data/validation/image_2/000105.png (deflated 3%)
# updating: data/validation/image_2/005462.png (deflated 3%)
# updating: data/validation/image_2/006414.png (deflated 3%)
# updating: data/validation/image_2/001913.png (deflated 3%)
# updating: data/validation/image_2/000896.png (deflated 3%)
# updating: data/validation/image_2/002668.png (deflated 3%)
# updating: data/validation/image_2/000367.png (deflated 3%)
# updating: data/validation/image_2/004641.png (deflated 3%)
# updating: data/validation/image_2/000602.png (deflated 3%)
# updating: data/validation/image_2/005169.png (deflated 3%)
# updating: data/validation/image_2/003597.png (deflated 3%)
# updating: data/validation/image_2/003906.png (deflated 3%)
# updating: data/validation/image_2/007058.png (deflated 3%)
# updating: data/validation/image_2/003966.png (deflated 3%)
# updating: data/validation/image_2/002654.png (deflated 3%)
# updating: data/validation/image_2/001030.png (deflated 3%)
# updating: data/validation/image_2/006352.png (deflated 3%)
# updating: data/validation/image_2/004908.png (deflated 3%)
# updating: data/validation/image_2/000514.png (deflated 3%)
# updating: data/validation/image_2/000051.png (deflated 3%)
# updating: data/validation/image_2/000091.png (deflated 3%)
# updating: data/validation/image_2/002264.png (deflated 3%)
# updating: data/validation/image_2/004479.png (deflated 3%)
# updating: data/validation/image_2/001685.png (deflated 3%)
# updating: data/validation/image_2/002331.png (deflated 3%)
# updating: data/validation/image_2/004245.png (deflated 3%)
# updating: data/validation/image_2/002596.png (deflated 3%)
# updating: data/validation/image_2/003013.png (deflated 3%)
# updating: data/validation/image_2/001687.png (deflated 3%)
# updating: data/validation/image_2/005615.png (deflated 2%)
# updating: data/validation/image_2/002819.png (deflated 2%)
# updating: data/validation/image_2/004313.png (deflated 2%)
# updating: data/validation/image_2/003246.png (deflated 1%)
# updating: data/validation/image_2/004431.png (deflated 2%)
# updating: data/validation/image_2/000228.png (deflated 2%)
# updating: data/validation/image_2/006911.png (deflated 3%)
# updating: data/validation/image_2/003790.png (deflated 3%)
# updating: data/validation/image_2/000713.png (deflated 2%)
# updating: data/validation/image_2/001895.png (deflated 3%)
# updating: data/validation/image_2/004923.png (deflated 3%)
# updating: data/validation/image_2/000490.png (deflated 3%)
# updating: data/validation/image_2/003933.png (deflated 3%)
# updating: data/validation/image_2/000131.png (deflated 3%)
# updating: data/validation/image_2/004919.png (deflated 3%)
# updating: data/validation/image_2/003039.png (deflated 2%)
# updating: data/validation/image_2/002825.png (deflated 2%)
# updating: data/validation/image_2/005675.png (deflated 2%)
# updating: data/validation/image_2/002926.png (deflated 2%)
# updating: data/validation/image_2/006958.png (deflated 3%)
# updating: data/validation/image_2/001850.png (deflated 3%)
# updating: data/validation/image_2/004617.png (deflated 3%)
# updating: data/validation/image_2/002859.png (deflated 2%)
# updating: data/validation/image_2/002533.png (deflated 2%)
# updating: data/validation/image_2/002940.png (deflated 2%)
# updating: data/validation/image_2/006788.png (deflated 2%)
# updating: data/validation/image_2/005987.png (deflated 2%)
# updating: data/validation/image_2/003844.png (deflated 2%)
# updating: data/validation/image_2/003545.png (deflated 2%)
# updating: data/validation/image_2/000016.png (deflated 2%)
# updating: data/validation/image_2/001595.png (deflated 2%)
# updating: data/validation/image_2/001060.png (deflated 2%)
# updating: data/validation/image_2/001472.png (deflated 2%)
# updating: data/validation/image_2/000067.png (deflated 2%)
# updating: data/validation/image_2/000079.png (deflated 3%)
# updating: data/validation/image_2/006438.png (deflated 3%)
# updating: data/validation/image_2/006432.png (deflated 2%)
# updating: data/validation/image_2/006307.png (deflated 2%)
# updating: data/validation/image_2/005795.png (deflated 2%)
# updating: data/validation/image_2/000121.png (deflated 2%)
# updating: data/validation/image_2/007013.png (deflated 2%)
# updating: data/validation/image_2/005261.png (deflated 2%)
# updating: data/validation/image_2/001470.png (deflated 2%)
# updating: data/validation/image_2/004236.png (deflated 3%)
# updating: data/validation/image_2/007066.png (deflated 2%)
# updating: data/validation/image_2/004341.png (deflated 3%)
# updating: data/validation/image_2/007316.png (deflated 2%)
# updating: data/validation/image_2/002547.png (deflated 2%)
# updating: data/validation/image_2/002614.png (deflated 2%)
# updating: data/validation/image_2/005200.png (deflated 2%)
# updating: data/validation/image_2/004286.png (deflated 3%)
# updating: data/validation/image_2/000296.png (deflated 3%)
# updating: data/validation/image_2/007020.png (deflated 2%)
# updating: data/validation/image_2/002381.png (deflated 2%)
# updating: data/validation/image_2/007171.png (deflated 2%)
# updating: data/validation/image_2/005575.png (deflated 2%)
# updating: data/validation/image_2/004910.png (deflated 2%)
# updating: data/validation/image_2/002172.png (deflated 2%)
# updating: data/validation/image_2/005721.png (deflated 3%)
# updating: data/validation/image_2/002371.png (deflated 2%)
# updating: data/validation/image_2/006775.png (deflated 2%)
# updating: data/validation/image_2/005069.png (deflated 2%)
# updating: data/validation/image_2/005412.png (deflated 2%)
# updating: data/validation/image_2/002253.png (deflated 2%)
# updating: data/validation/image_2/002481.png (deflated 2%)
# updating: data/validation/image_2/001652.png (deflated 3%)
# updating: data/validation/image_2/001430.png (deflated 2%)
# updating: data/validation/image_2/003360.png (deflated 3%)
# updating: data/validation/image_2/002791.png (deflated 2%)
# updating: data/validation/image_2/004018.png (deflated 3%)
# updating: data/validation/image_2/003606.png (deflated 3%)
# updating: data/validation/image_2/006255.png (deflated 3%)
# updating: data/validation/image_2/007457.png (deflated 3%)
# updating: data/validation/image_2/000018.png (deflated 3%)
# updating: data/validation/image_2/001532.png (deflated 3%)
# updating: data/validation/image_2/004775.png (deflated 3%)
# updating: data/validation/image_2/004645.png (deflated 2%)
# updating: data/validation/image_2/003184.png (deflated 2%)
# updating: data/validation/image_2/006203.png (deflated 2%)
# updating: data/validation/image_2/003871.png (deflated 2%)
# updating: data/validation/image_2/006740.png (deflated 2%)
# updating: data/validation/image_2/007213.png (deflated 2%)
# updating: data/validation/image_2/006933.png (deflated 2%)
# updating: data/validation/image_2/005025.png (deflated 2%)
# updating: data/validation/image_2/003415.png (deflated 2%)
# updating: data/validation/image_2/004586.png (deflated 2%)
# updating: data/validation/image_2/000815.png (deflated 2%)
# updating: data/validation/image_2/004227.png (deflated 3%)
# updating: data/validation/image_2/004784.png (deflated 2%)
# updating: data/validation/image_2/001637.png (deflated 2%)
# updating: data/validation/image_2/001402.png (deflated 2%)
# updating: data/validation/image_2/004097.png (deflated 2%)
# updating: data/validation/image_2/002261.png (deflated 3%)
# updating: data/validation/image_2/001799.png (deflated 2%)
# updating: data/validation/image_2/004144.png (deflated 2%)
# updating: data/validation/image_2/002125.png (deflated 2%)
# updating: data/validation/image_2/004197.png (deflated 2%)
# updating: data/validation/image_2/000007.png (deflated 2%)
# updating: data/validation/image_2/004690.png (deflated 2%)
# updating: data/validation/image_2/000150.png (deflated 2%)
# updating: data/validation/image_2/001455.png (deflated 2%)
# updating: data/validation/image_2/003626.png (deflated 2%)
# updating: data/validation/image_2/003619.png (deflated 2%)
# updating: data/validation/image_2/001918.png (deflated 2%)
# updating: data/validation/image_2/004382.png (deflated 2%)
# updating: data/validation/image_2/000585.png (deflated 2%)
# updating: data/validation/image_2/006717.png (deflated 2%)
# updating: data/validation/image_2/006413.png (deflated 2%)
# updating: data/validation/image_2/001168.png (deflated 2%)
# updating: data/validation/image_2/003157.png (deflated 2%)
# updating: data/validation/image_2/003501.png (deflated 2%)
# updating: data/validation/image_2/001157.png (deflated 2%)
# updating: data/validation/image_2/004084.png (deflated 2%)
# updating: data/validation/image_2/002623.png (deflated 2%)
# updating: data/validation/image_2/004371.png (deflated 2%)
# updating: data/validation/image_2/004736.png (deflated 3%)
# updating: data/validation/image_2/004558.png (deflated 2%)
# updating: data/validation/image_2/005083.png (deflated 2%)
# updating: data/validation/image_2/003015.png (deflated 2%)
# updating: data/validation/image_2/000310.png (deflated 2%)
# updating: data/validation/image_2/007414.png (deflated 3%)
# updating: data/validation/image_2/000339.png (deflated 3%)
# updating: data/validation/image_2/002024.png (deflated 3%)
# updating: data/validation/image_2/000685.png (deflated 3%)
# updating: data/validation/image_2/000256.png (deflated 3%)
# updating: data/validation/image_2/006072.png (deflated 2%)
# updating: data/validation/image_2/007390.png (deflated 3%)
# updating: data/validation/image_2/004899.png (deflated 2%)
# updating: data/validation/image_2/006610.png (deflated 3%)
# updating: data/validation/image_2/005520.png (deflated 2%)
# updating: data/validation/image_2/002913.png (deflated 2%)
# updating: data/validation/image_2/003743.png (deflated 4%)
# updating: data/validation/image_2/006924.png (deflated 3%)
# updating: data/validation/image_2/001401.png (deflated 4%)
# updating: data/validation/image_2/003612.png (deflated 4%)
# updating: data/validation/image_2/003868.png (deflated 3%)
# updating: data/validation/image_2/006893.png (deflated 4%)
# updating: data/validation/image_2/000538.png (deflated 4%)
# updating: data/validation/image_2/003108.png (deflated 3%)
# updating: data/validation/image_2/007197.png (deflated 3%)
# updating: data/validation/image_2/001950.png (deflated 3%)
# updating: data/validation/image_2/005792.png (deflated 2%)
# updating: data/validation/image_2/000908.png (deflated 2%)
# updating: data/validation/image_2/002032.png (deflated 2%)
# updating: data/validation/image_2/004952.png (deflated 2%)
# updating: data/validation/image_2/005715.png (deflated 1%)
# updating: data/validation/image_2/003245.png (deflated 1%)
# updating: data/validation/image_2/006112.png (deflated 2%)
# updating: data/validation/image_2/005232.png (deflated 1%)
# updating: data/validation/image_2/005215.png (deflated 0%)
# updating: data/validation/image_2/000097.png (deflated 0%)
# updating: data/validation/image_2/001420.png (deflated 0%)
# updating: data/validation/image_2/000220.png (deflated 0%)
# updating: data/validation/image_2/000794.png (deflated 0%)
# updating: data/validation/image_2/006323.png (deflated 1%)
# updating: data/validation/image_2/002466.png (deflated 1%)
# updating: data/validation/image_2/005506.png (deflated 1%)
# updating: data/validation/image_2/000813.png (deflated 1%)
# updating: data/validation/image_2/001987.png (deflated 1%)
# updating: data/validation/image_2/004358.png (deflated 1%)
# updating: data/validation/image_2/003861.png (deflated 1%)
# updating: data/validation/image_2/002802.png (deflated 1%)
# updating: data/validation/image_2/000830.png (deflated 1%)
# updating: data/validation/image_2/005517.png (deflated 0%)
# updating: data/validation/image_2/003556.png (deflated 0%)
# updating: data/validation/image_2/007334.png (deflated 1%)
# updating: data/validation/image_2/005991.png (deflated 1%)
# updating: data/validation/image_2/003195.png (deflated 1%)
# updating: data/validation/image_2/003286.png (deflated 1%)
# updating: data/validation/image_2/006109.png (deflated 1%)
# updating: data/validation/image_2/004057.png (deflated 1%)
# updating: data/validation/image_2/003664.png (deflated 1%)
# updating: data/validation/image_2/005235.png (deflated 1%)
# updating: data/validation/image_2/000087.png (deflated 1%)
# updating: data/validation/image_2/001766.png (deflated 1%)
# updating: data/validation/image_2/004561.png (deflated 1%)
# updating: data/validation/image_2/006293.png (deflated 0%)
# updating: data/validation/image_2/003912.png (deflated 1%)
# updating: data/validation/image_2/001523.png (deflated 0%)
# updating: data/validation/image_2/004328.png (deflated 0%)
# updating: data/validation/image_2/002084.png (deflated 0%)
# updating: data/validation/image_2/003391.png (deflated 0%)
# updating: data/validation/image_2/000763.png (deflated 0%)
# updating: data/validation/image_2/000846.png (deflated 0%)
# updating: data/validation/image_2/000127.png (deflated 0%)
# updating: data/validation/image_2/000868.png (deflated 0%)
# updating: data/validation/image_2/002322.png (deflated 1%)
# updating: data/validation/image_2/003260.png (deflated 0%)
# updating: data/validation/image_2/002096.png (deflated 1%)
# updating: data/validation/image_2/004945.png (deflated 1%)
# updating: data/validation/image_2/003641.png (deflated 1%)
# updating: data/validation/image_2/006842.png (deflated 1%)
# updating: data/validation/image_2/005773.png (deflated 1%)
# updating: data/validation/image_2/000632.png (deflated 1%)
# updating: data/validation/image_2/005579.png (deflated 1%)
# updating: data/validation/image_2/006564.png (deflated 1%)
# updating: data/validation/image_2/005102.png (deflated 1%)
# updating: data/validation/image_2/000154.png (deflated 1%)
# updating: data/validation/image_2/004964.png (deflated 1%)
# updating: data/validation/image_2/002973.png (deflated 1%)
# updating: data/validation/image_2/002571.png (deflated 1%)
# updating: data/validation/image_2/000902.png (deflated 0%)
# updating: data/validation/image_2/004499.png (deflated 1%)
# updating: data/validation/image_2/005043.png (deflated 0%)
# updating: data/validation/image_2/004090.png (deflated 0%)
# updating: data/validation/image_2/001378.png (deflated 0%)
# updating: data/validation/image_2/003057.png (deflated 0%)
# updating: data/validation/image_2/003722.png (deflated 0%)
# updating: data/validation/image_2/004796.png (deflated 0%)
# updating: data/validation/image_2/003336.png (deflated 0%)
# updating: data/validation/image_2/006536.png (deflated 0%)
# updating: data/validation/image_2/001184.png (deflated 0%)
# updating: data/validation/image_2/006985.png (deflated 0%)
# updating: data/validation/image_2/002047.png (deflated 1%)
# updating: data/validation/image_2/003850.png (deflated 1%)
# updating: data/validation/image_2/003710.png (deflated 2%)
# updating: data/validation/image_2/002910.png (deflated 1%)
# updating: data/validation/image_2/000326.png (deflated 2%)
# updating: data/validation/image_2/003111.png (deflated 2%)
# updating: data/validation/image_2/004922.png (deflated 1%)
# updating: data/validation/image_2/006374.png (deflated 1%)
# updating: data/validation/image_2/001313.png (deflated 1%)
# updating: data/validation/image_2/005451.png (deflated 1%)
# updating: data/validation/image_2/003925.png (deflated 1%)
# updating: data/validation/image_2/000617.png (deflated 2%)
# updating: data/validation/image_2/000267.png (deflated 2%)
# updating: data/validation/image_2/006975.png (deflated 2%)
# updating: data/validation/image_2/003776.png (deflated 0%)
# updating: data/validation/image_2/001737.png (deflated 2%)
# updating: data/validation/image_2/001098.png (deflated 1%)
# updating: data/validation/image_2/006823.png (deflated 2%)
# updating: data/validation/image_2/001935.png (deflated 1%)
# updating: data/validation/image_2/004046.png (deflated 0%)
# updating: data/validation/image_2/003952.png (deflated 1%)
# updating: data/validation/image_2/006443.png (deflated 1%)
# updating: data/validation/image_2/006375.png (deflated 2%)
# updating: data/trainval.txt (deflated 71%)
# updating: data/test.txt (deflated 71%)
# updating: data/val.txt (deflated 69%)
# updating: data/train.txt (deflated 69%)
# updating: data/split.py (deflated 74%)
#   adding: data/dataset.py (deflated 73%)
#   adding: data/__pycache__/ (stored 0%)
#   adding: data/__pycache__/dataset.cpython-37.pyc (deflated 49%)
